# %%
# !pip install totalsegmentator
# Out:
# ...
#   Using cached TotalSegmentator-2.0.5-py3-none-any.whl (54 kB)
# ...
#      |████████████████████████████████| 43 kB 1.5 MB/s eta 0:00:011
# ...
#   Using cached SimpleITK-2.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.6 MB)
# ...
#   Using cached xvfbwrapper-0.2.9-py3-none-any.whl
# ...
#   Using cached fury-0.9.0-py3-none-any.whl (510 kB)
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# ...
#   Using cached rt_utils-1.2.7-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached p_tqdm-1.4.0-py3-none-any.whl
# ...
#   Using cached torch-2.1.0-cp39-cp39-manylinux1_x86_64.whl (670.2 MB)
# ...
#   Using cached nibabel-5.1.0-py3-none-any.whl (3.3 MB)
# ...
#   Using cached nnunetv2-2.1-py3-none-any.whl
# ...
#   Using cached batchgenerators-0.25-py3-none-any.whl
# ...
#   Using cached MedPy-0.4.0-py3-none-any.whl
# ...
#   Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# ...
#   Using cached scikit_image-0.22.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
# ...

# %%
from totalsegmentator.python_api import totalsegmentator
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4061443/1144508404.py in <module>
# ----> 1 from totalsegmentator.python_api import totalsegmentator
#
# ~/miniconda3/envs/TS/lib/python3.9/site-packages/totalsegmentator/python_api.py in <module>
#       7 import numpy as np
#       8 import nibabel as nib
# ----> 9 import torch
#      10
#      11 from totalsegmentator.statistics import get_basic_statistics, get_radiomics_features_for_entire_dir
#
# ~/miniconda3/envs/TS/lib/python3.9/site-packages/torch/__init__.py in <module>
#     463     raise  # If __file__ is not None the cause is unknown, so just re-raise.
#     464
# --> 465 for name in dir(_C):
#     466     if name[0] != '_' and not name.endswith('Base'):
#     467         __all__.append(name)
#
# NameError: name '_C' is not defined

# %%
input_path = 'ESUS_niigz/10.image.nii.gz'

# %%
output_path = 'output/'

# %%
totalsegmentator(input_path, output_path)
# Out:
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2791608/1159076449.py in <module>
# ----> 1 totalsegmentator(input_path, output_path)
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/totalsegmentator/python_api.py in totalsegmentator(input, output, ml, nr_thr_resamp, nr_thr_saving, fast, nora_tag, preview, task, roi_subset, statistics, radiomics, crop_path, body_seg, force_split, output_type, quiet, verbose, test, skip_saving, device, license_number, statistics_exclude_masks_at_border, no_derived_masks, v1_order)
#      75         set_config_key("statistics_disclaimer_shown", True)
#      76
# ---> 77     from totalsegmentator.nnunet import nnUNet_predict_image  # this has to be after setting new env vars
#      78
#      79     crop_addon = [3, 3, 3]  # default value
#
# ...
