# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cactas as C
# Out:
# 2024-05-20 17:38:12.607821: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
DATAPATH='/raid/mpsych/CACTAS/DATA/ESUS'
CAPATH='/raid/mpsych/CACTAS/DATA/CA24'

# %%
#### 1

# %%
images, labels = C.Helper.load_data(DATAPATH)

# %%
masks = C.Helper.load_seg_data(CAPATH)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.split_patients_masks(images, labels, masks)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.normalization2(DATAPATH, CAPATH, X_train, y_train, m_train, X_test, y_test, m_test)

# %%
X_train, y_train, X_test, y_test = C.Helper.extract_slices(X_train, y_train, X_test, y_test)
# Out:
# (13186, 512, 512, 1) (13186, 512, 512, 1) (3580, 512, 512, 1) (3580, 512, 512, 1)

# %%
m_train, m_test = C.Helper.extract_masks_slices(m_train, m_test)
# Out:
# (13186, 512, 512, 1) (3580, 512, 512, 1)

# %%
X_train, y_train, m_train = C.Helper.filter_slices(X_train, y_train, m_train)
# Out:
# (627, 512, 512, 1) (627, 512, 512, 1) (627, 512, 512, 1)

# %%
train_images_array, test_images_array = C.Helper.masked_image(X_train, m_train, X_test, m_test)
# Out:
# (627, 512, 512, 1) (3580, 512, 512, 1)

# %%
for i in range(5):
    plt.imshow(train_images_array[i,:,:])
    plt.show()

# %%
for i in range(100,105):
    plt.imshow(test_images_array[i,:,:])
    plt.show()

# %%
#### 2

# %%
images, labels = C.Helper.load_data(DATAPATH)

# %%
masks = C.Helper.load_seg_data(CAPATH)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.split_patients_masks(images, labels, masks)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.normalization2(DATAPATH, CAPATH, X_train, y_train, m_train, X_test, y_test, m_test)

# %%
X_train, y_train, X_test, y_test = C.Helper.extract_slices(X_train, y_train, X_test, y_test)
# Out:
# (13513, 512, 512, 1) (13513, 512, 512, 1) (3253, 512, 512, 1) (3253, 512, 512, 1)

# %%
m_train, m_test = C.Helper.extract_masks_slices(m_train, m_test)
# Out:
# (13513, 512, 512, 1) (3253, 512, 512, 1)

# %%
X_train, y_train, m_train = C.Helper.filter_slices(X_train, y_train, m_train)
# Out:
# (587, 512, 512, 1) (587, 512, 512, 1) (587, 512, 512, 1)

# %%
train_images_array, test_images_array = C.Helper.masked_image(X_train, m_train, X_test, m_test)
# Out:
# (587, 512, 512, 1) (3253, 512, 512, 1)

# %%
for i in range(5):
    plt.imshow(train_images_array[i,:,:])
    plt.show()

# %%
for i in range(100,105):
    plt.imshow(test_images_array[i,:,:])
    plt.show()

# %%
#### 3

# %%
images, labels = C.Helper.load_data(DATAPATH)

# %%
masks = C.Helper.load_seg_data(CAPATH)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.split_patients_masks(images, labels, masks)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.normalization2(DATAPATH, CAPATH, X_train, y_train, m_train, X_test, y_test, m_test)

# %%
X_train, y_train, X_test, y_test = C.Helper.extract_slices(X_train, y_train, X_test, y_test)
# Out:
# (13309, 512, 512, 1) (13309, 512, 512, 1) (3457, 512, 512, 1) (3457, 512, 512, 1)

# %%
m_train, m_test = C.Helper.extract_masks_slices(m_train, m_test)
# Out:
# (13309, 512, 512, 1) (3457, 512, 512, 1)

# %%
X_train, y_train, m_train = C.Helper.filter_slices(X_train, y_train, m_train)
# Out:
# (541, 512, 512, 1) (541, 512, 512, 1) (541, 512, 512, 1)

# %%
train_images_array, test_images_array = C.Helper.masked_image(X_train, m_train, X_test, m_test)
# Out:
# (541, 512, 512, 1) (3457, 512, 512, 1)

# %%
for i in range(5):
    plt.imshow(train_images_array[i,:,:])
    plt.show()

# %%
for i in range(80,85):
    plt.imshow(test_images_array[i,:,:])
    plt.show()
