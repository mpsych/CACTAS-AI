# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import nrrd
from scipy.ndimage import binary_fill_holes

# %%
image, h1 = nrrd.read('/home/jiehyun.kim001/CACTAS/data/subvol.nrrd')
label_data, h2 = nrrd.read('/home/jiehyun.kim001/CACTAS/data/morga_20200507__wallThickness.nrrd')

# %%
image.shape, label_data.shape
# Out:
# ((57, 125, 68), (57, 125, 68))

# %%
# change to binary label
binary_label = np.zeros_like(label_data)
binary_label[label_data > 0] = 1

# %%
# fill out inside of the label
filled_image = np.zeros_like(binary_label)
for i in range(binary_label.shape[2]):
    filled_image[:, :, i] = binary_fill_holes(binary_label[:, :, i])

# %%
# visualize image
for i in range(image.shape[2]):
    plt.imshow(filled_image[:, :, i], cmap='gray')
    plt.show()
