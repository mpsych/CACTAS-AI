# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import nrrd

# %%
DATAPATH='/home/jiehyun.kim001/ELUCID/DATA/'

# %%
img = DATAPATH + 'subvol.nrrd'
seg = DATAPATH + 'SongJa_20231208__composition.multi.nrrd'

# %%
image, header1 = nrrd.read(img)
label, header2 = nrrd.read(seg)

# %%
image.shape, label.shape
# Out:
# ((153, 217, 36), (153, 217, 36, 5))

# %%
result_array = (label > 0).astype(np.uint8)

# %%
result_array = result_array.reshape(result_array.shape[3],result_array.shape[0],result_array.shape[1],result_array.shape[2])

# %%
result_array.shape
# Out:
# (5, 153, 217, 36)

# %%
########ALL

# %%
plt.imshow(image[:,:,2])
plt.imshow(result_array[0][:,:,2], alpha=0.5)
plt.imshow(result_array[1][:,:,2], alpha=0.5)
plt.imshow(result_array[2][:,:,2], alpha=0.5)
plt.imshow(result_array[3][:,:,2], alpha=0.5)
plt.imshow(result_array[4][:,:,2], alpha=0.5)
plt.show()

# %%
########1

# %%
plt.imshow(image[:,:,2])
plt.imshow(result_array[0][:,:,2], alpha=0.5)
plt.show()

# %%
########2

# %%
plt.imshow(image[:,:,2])
plt.imshow(result_array[1][:,:,2],alpha=0.5)
plt.show()

# %%
#######3

# %%
plt.imshow(image[:,:,2])
plt.imshow(result_array[2][:,:,2], alpha=0.5)
plt.show()

# %%
#######4

# %%
plt.imshow(image[:,:,2])
plt.imshow(result_array[3][:,:,2], alpha=0.5)
plt.show()

# %%
#######5

# %%
plt.imshow(image[:,:,2])
plt.imshow(result_array[4][:,:,2], alpha=0.5)
plt.show()

# %%
'''
for i in range(image.shape[2]):
    plt.imshow(image[:,:,i])
    plt.imshow(result_array[0][:,:,i], alpha=0.5)
    plt.imshow(result_array[1][:,:,i], alpha=0.5)
    plt.imshow(result_array[2][:,:,i], alpha=0.5)
    plt.imshow(result_array[3][:,:,i], alpha=0.5)
    plt.imshow(result_array[4][:,:,i], alpha=0.5)
    plt.show()
'''
# Out:
# '\nfor i in range(image.shape[2]):\n    plt.imshow(image[:,:,i])\n    plt.imshow(result_array[0][:,:,i], alpha=0.5)\n    plt.imshow(result_array[1][:,:,i], alpha=0.5)\n    plt.imshow(result_array[2][:,:,i], alpha=0.5)\n    plt.imshow(result_array[3][:,:,i], alpha=0.5)\n    plt.imshow(result_array[4][:,:,i], alpha=0.5)\n    plt.show()\n'

# %%
'''
for i in range(image.shape[2]):
    plt.imshow(image[:,:,i])
    plt.imshow(result_array[0][:,:,i], alpha=0.5)
    #plt.imshow(result_array[1][:,:,i], alpha=0.5)
    #plt.imshow(result_array[2][:,:,i], alpha=0.5)
    #plt.imshow(result_array[3][:,:,i], alpha=0.5)
    #plt.imshow(result_array[4][:,:,i], alpha=0.5)
    plt.show()
'''
# Out:
# '\nfor i in range(image.shape[2]):\n    plt.imshow(image[:,:,i])\n    plt.imshow(result_array[0][:,:,i], alpha=0.5)\n    #plt.imshow(result_array[1][:,:,i], alpha=0.5)\n    #plt.imshow(result_array[2][:,:,i], alpha=0.5)\n    #plt.imshow(result_array[3][:,:,i], alpha=0.5)\n    #plt.imshow(result_array[4][:,:,i], alpha=0.5)\n    plt.show()\n'

# %%
'''
for i in range(image.shape[2]):
    plt.imshow(image[:,:,i])
    #plt.imshow(result_array[0][:,:,i],alpha=0.5)
    plt.imshow(result_array[1][:,:,i],alpha=0.5)
    #plt.imshow(result_array[2][:,:,i],alpha=0.5)
    #plt.imshow(result_array[3][:,:,i],alpha=0.5)
    #plt.imshow(result_array[4][:,:,i],alpha=0.5)
    plt.show()
'''
# Out:
# '\nfor i in range(image.shape[2]):\n    plt.imshow(image[:,:,i])\n    #plt.imshow(result_array[0][:,:,i],alpha=0.5)\n    plt.imshow(result_array[1][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[2][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[3][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[4][:,:,i],alpha=0.5)\n    plt.show()\n'

# %%
'''
for i in range(image.shape[2]):
    plt.imshow(image[:,:,i])
    #plt.imshow(result_array[0][:,:,i],alpha=0.5)
    #plt.imshow(result_array[1][:,:,i],alpha=0.5)
    plt.imshow(result_array[2][:,:,i],alpha=0.5)
    #plt.imshow(result_array[3][:,:,i],alpha=0.5)
    #plt.imshow(result_array[4][:,:,i],alpha=0.5)
    plt.show()
'''
# Out:
# '\nfor i in range(image.shape[2]):\n    plt.imshow(image[:,:,i])\n    #plt.imshow(result_array[0][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[1][:,:,i],alpha=0.5)\n    plt.imshow(result_array[2][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[3][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[4][:,:,i],alpha=0.5)\n    plt.show()\n'

# %%
'''
for i in range(image.shape[2]):
    plt.imshow(image[:,:,i])
    #plt.imshow(result_array[0][:,:,i],alpha=0.5)
    #plt.imshow(result_array[1][:,:,i],alpha=0.5)
    #plt.imshow(result_array[2][:,:,i],alpha=0.5)
    plt.imshow(result_array[3][:,:,i],alpha=0.5)
    #plt.imshow(result_array[4][:,:,i],alpha=0.5)
    plt.show()
'''
# Out:
# '\nfor i in range(image.shape[2]):\n    plt.imshow(image[:,:,i])\n    #plt.imshow(result_array[0][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[1][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[2][:,:,i],alpha=0.5)\n    plt.imshow(result_array[3][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[4][:,:,i],alpha=0.5)\n    plt.show()\n'

# %%
'''
for i in range(image.shape[2]):
    plt.imshow(image[:,:,i])
    #plt.imshow(result_array[0][:,:,i],alpha=0.5)
    #plt.imshow(result_array[1][:,:,i],alpha=0.5)
    #plt.imshow(result_array[2][:,:,i],alpha=0.5)
    #plt.imshow(result_array[3][:,:,i],alpha=0.5)
    plt.imshow(result_array[4][:,:,i],alpha=0.5)
    plt.show()
'''
# Out:
# '\nfor i in range(image.shape[2]):\n    plt.imshow(image[:,:,i])\n    #plt.imshow(result_array[0][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[1][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[2][:,:,i],alpha=0.5)\n    #plt.imshow(result_array[3][:,:,i],alpha=0.5)\n    plt.imshow(result_array[4][:,:,i],alpha=0.5)\n    plt.show()\n'
