# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cactas as C
# Out:
# 2024-05-20 17:03:03.446204: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
DATAPATH='/raid/mpsych/CACTAS/DATA/ESUS'
CAPATH='/raid/mpsych/CACTAS/DATA/CA24'

# %%
#### 1

# %%
images, labels = C.Helper.load_data(DATAPATH)

# %%
masks = C.Helper.load_seg_data(CAPATH)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.split_patients_masks(images, labels, masks)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.normalization2(DATAPATH, CAPATH, X_train, y_train, m_train, X_test, y_test, m_test)

# %%
X_train, y_train, X_test, y_test = C.Helper.extract_slices(X_train, y_train, X_test, y_test)
# Out:
# (13411, 512, 512, 1) (13411, 512, 512, 1) (3355, 512, 512, 1) (3355, 512, 512, 1)

# %%
m_train, m_test = C.Helper.extract_masks_slices(m_train, m_test)
# Out:
# (13411, 512, 512, 1) (3355, 512, 512, 1)

# %%
X_train, y_train, m_train = C.Helper.filter_slices(X_train, y_train, m_train)
# Out:
# (539, 512, 512, 1) (539, 512, 512, 1) (539, 512, 512, 1)

# %%
for i in range(5):
    plt.imshow(X_train[i,:,:])
    plt.imshow(y_train[i,:,:], cmap='gray', alpha= 0.5)
    plt.imshow(m_train[i,:,:], alpha= 0.5)
    plt.show()

# %%
#### 2

# %%
images, labels = C.Helper.load_data(DATAPATH)

# %%
masks = C.Helper.load_seg_data(CAPATH)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.split_patients_masks(images, labels, masks)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.normalization2(DATAPATH, CAPATH, X_train, y_train, m_train, X_test, y_test, m_test)

# %%
X_train, y_train, X_test, y_test = C.Helper.extract_slices(X_train, y_train, X_test, y_test)
# Out:
# (13613, 512, 512, 1) (13613, 512, 512, 1) (3153, 512, 512, 1) (3153, 512, 512, 1)

# %%
m_train, m_test = C.Helper.extract_masks_slices(m_train, m_test)
# Out:
# (13613, 512, 512, 1) (3153, 512, 512, 1)

# %%
X_train, y_train, m_train = C.Helper.filter_slices(X_train, y_train, m_train)
# Out:
# (542, 512, 512, 1) (542, 512, 512, 1) (542, 512, 512, 1)

# %%
for i in range(5):
    plt.imshow(X_train[i,:,:])
    plt.imshow(y_train[i,:,:], cmap='gray', alpha= 0.5)
    plt.imshow(m_train[i,:,:], alpha= 0.5)
    plt.show()

# %%
#### 3

# %%
images, labels = C.Helper.load_data(DATAPATH)

# %%
masks = C.Helper.load_seg_data(CAPATH)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.split_patients_masks(images, labels, masks)

# %%
X_train, y_train, m_train, X_test, y_test, m_test = C.Helper.normalization2(DATAPATH, CAPATH, X_train, y_train, m_train, X_test, y_test, m_test)

# %%
X_train, y_train, X_test, y_test = C.Helper.extract_slices(X_train, y_train, X_test, y_test)
# Out:
# (13432, 512, 512, 1) (13432, 512, 512, 1) (3334, 512, 512, 1) (3334, 512, 512, 1)

# %%
m_train, m_test = C.Helper.extract_masks_slices(m_train, m_test)
# Out:
# (13432, 512, 512, 1) (3334, 512, 512, 1)

# %%
X_train, y_train, m_train = C.Helper.filter_slices(X_train, y_train, m_train)
# Out:
# (595, 512, 512, 1) (595, 512, 512, 1) (595, 512, 512, 1)

# %%
for i in range(5):
    plt.imshow(X_train[i,:,:])
    plt.imshow(y_train[i,:,:], cmap='gray', alpha= 0.5)
    plt.imshow(m_train[i,:,:], alpha= 0.5)
    plt.show()
