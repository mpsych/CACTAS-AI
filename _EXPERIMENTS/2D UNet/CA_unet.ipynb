# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cactas as C

# %%
import tensorflow as tf
import os
import nrrd
import pickle

# %%
DATAPATH='/raid/mpsych/CACTAS/DATA/ESUS'
CAPATH='/raid/mpsych/CACTAS/DATA/CA_ESUS35/'

# %%
images, labels = C.Helper.load_data(DATAPATH)

# %%
masks = C.Helper.load_seg_data(CAPATH)

# %%
len(images), len(labels), len(masks)
# Out:
# (70, 70, 70)

# %%
numbers = []
for filename in images:
    number = filename.split(".")[0]
    numbers.append(number)

label_dict = {}
for filename in labels:
    num = filename.split(".")[0]
    label_dict[num] = filename

mask_dict = {}
for filename in masks:
    num = filename.split(".")[0]
    mask_dict[num] = filename

data = []
for filename in images:
    number = filename.split(".")[0]
    data.append((filename, label_dict[number], mask_dict[number]))

random.shuffle(data)

images = [item[0] for item in data]
labels = [item[1] for item in data]
masks = [item[2] for item in data]

# %%
X_train = []
y_train = []
m_train = []

# %%
for file in images:
    data, header = nrrd.read(DATAPATH + "/" +file)
    normalized_data = (data - np.min(data)) / (np.max(data) - np.min(data))
    X_train.append(normalized_data)

# %%
for file in labels:
    data, header = nrrd.read(DATAPATH + "/" +file)
    y_train.append(normalized_data)

# %%
for file in masks:
    data, header = nrrd.read(CAPATH + "/" +file)
    normalized_data = (data - np.min(data)) / (np.max(data) - np.min(data))
    m_train.append(normalized_data)

# %%
len(X_train), len(y_train), len(m_train)
# Out:
# (70, 70, 70)

# %%
slice_to_patient_mapping, last_key = C.Helper.map_and_key_fulldata(y_train)
# Out:
# 13495

# %%
# Image
slices = []
for i in range(len(X_train)):
    for z in range(X_train[i].shape[2]):
        slice_2d = X_train[i][:, :, z]
        slices.append(slice_2d)
X_train_array = np.array(slices)

# %%
# Mask
slices_mtrain=[]
for i in range(len(m_train)):
    for z in range(m_train[i].shape[2]):
        slice_2d = m_train[i][:, :, z]
        slices_mtrain.append(slice_2d)
m_train_array = np.array(slices_mtrain)

# %%
X_train_array = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1],X_train_array.shape[2], 1)
m_train_array = m_train_array.reshape(m_train_array.shape[0], m_train_array.shape[1],m_train_array.shape[2], 1)

# %%
print(X_train_array.shape, m_train_array.shape)
# Out:
# (16766, 512, 512, 1) (16766, 512, 512, 1)

# %%
X_train_set = X_train_array[:last_key]
y_train_set = m_train_array[:last_key]
X_val = X_train_array[last_key:]
y_val = m_train_array[last_key:]

# %%
X_train_set.dtype, y_train_set.dtype, X_val.dtype, y_val.dtype
# Out:
# (dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'))

# %%
model = C.Helper.create_unet(X_train_set[0].shape)
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------
# 2024-09-27 04:30:47.122717: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2024-09-27 04:30:47.796041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:0f:00.0 name: NVIDIA A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.39GiB deviceMemoryBandwidth: 1.41TiB/s
# 2024-09-27 04:30:47.805617: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:bd:00.0 name: NVIDIA A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.39GiB deviceMemoryBandwidth: 1.41TiB/s
# 2024-09-27 04:30:47.805642: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2024-09-27 04:30:47.830250: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2024-09-27 04:30:47.830291: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2024-09-27 04:30:47.837486: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2024-09-27 04:30:47.840584: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2024-09-27 04:30:47.843648: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2024-09-27 04:30:47.849276: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2024-09-27 04:30:47.850687: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2024-09-27 04:30:47.864471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1
# 2024-09-27 04:30:47.866365: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-27 04:30:48.258571: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:0f:00.0 name: NVIDIA A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.39GiB deviceMemoryBandwidth: 1.41TiB/s
# 2024-09-27 04:30:48.260260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:bd:00.0 name: NVIDIA A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.39GiB deviceMemoryBandwidth: 1.41TiB/s
# 2024-09-27 04:30:48.266505: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1
# 2024-09-27 04:30:48.266948: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2024-09-27 04:30:49.288615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-09-27 04:30:49.288670: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1
# 2024-09-27 04:30:49.288676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y
# 2024-09-27 04:30:49.288680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N
# 2024-09-27 04:30:49.297104: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38230 MB memory) -> physical GPU (device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0)
# 2024-09-27 04:30:49.300812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 38230 MB memory) -> physical GPU (device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0)

# %%
model, history = C.Helper.train_unet(X_train_set, y_train_set, X_val, y_val, model, epochs=200)
# Out:
# 2024-09-27 04:31:05.385534: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2024-09-27 04:31:05.406565: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245750000 Hz
# Epoch 1/200
# 2024-09-27 04:31:07.052491: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2024-09-27 04:31:07.818178: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2024-09-27 04:31:08.850221: W tensorflow/stream_executor/gpu/asm_compiler.cc:191] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2024-09-27 04:31:08.850245: W tensorflow/stream_executor/gpu/asm_compiler.cc:194] Used ptxas at ptxas
# 2024-09-27 04:31:08.850608: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Unimplemented: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-09-27 04:31:08.932399: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2024-09-27 04:31:09.887436: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 843/843 [==============================] - 403s 463ms/step - loss: 0.0819 - iou: 5.3637e-04 - iou_thresholded: 0.0851 - val_loss: 0.0058 - val_iou: 3.4562e-04 - val_iou_thresholded: 0.7919
# Epoch 2/200
# 843/843 [==============================] - 388s 457ms/step - loss: 0.0036 - iou: 0.0027 - iou_thresholded: 0.1069 - val_loss: 0.0042 - val_iou: 8.4396e-04 - val_iou_thresholded: 0.8245
# Epoch 3/200
# 843/843 [==============================] - 384s 455ms/step - loss: 0.0028 - iou: 0.0111 - iou_thresholded: 0.1128 - val_loss: 0.0036 - val_iou: 0.0037 - val_iou_thresholded: 0.8245
# Epoch 4/200
# 843/843 [==============================] - 385s 456ms/step - loss: 0.0025 - iou: 0.0229 - iou_thresholded: 0.1017 - val_loss: 0.0043 - val_iou: 9.3873e-04 - val_iou_thresholded: 0.8245
# Epoch 5/200
# 843/843 [==============================] - 385s 456ms/step - loss: 0.0023 - iou: 0.0365 - iou_thresholded: 0.1102 - val_loss: 0.0034 - val_iou: 0.0141 - val_iou_thresholded: 0.6628
# Epoch 6/200
# 843/843 [==============================] - 384s 455ms/step - loss: 0.0022 - iou: 0.0416 - iou_thresholded: 0.1208 - val_loss: 0.0029 - val_iou: 0.0169 - val_iou_thresholded: 0.6892
# Epoch 7/200
# 843/843 [==============================] - 385s 456ms/step - loss: 0.0021 - iou: 0.0496 - iou_thresholded: 0.1468 - val_loss: 0.0038 - val_iou: 0.0038 - val_iou_thresholded: 0.8245
# Epoch 8/200
# 843/843 [==============================] - 384s 456ms/step - loss: 0.0021 - iou: 0.0501 - iou_thresholded: 0.1528 - val_loss: 0.0033 - val_iou: 0.0118 - val_iou_thresholded: 0.7318
# Epoch 9/200
# 843/843 [==============================] - 383s 454ms/step - loss: 0.0018 - iou: 0.0674 - iou_thresholded: 0.1700 - val_loss: 0.0028 - val_iou: 0.0203 - val_iou_thresholded: 0.7809
# Epoch 10/200
# 843/843 [==============================] - 382s 453ms/step - loss: 0.0019 - iou: 0.0745 - iou_thresholded: 0.1930 - val_loss: 0.0030 - val_iou: 0.0091 - val_iou_thresholded: 0.8126
# Epoch 11/200
# 843/843 [==============================] - 382s 453ms/step - loss: 0.0018 - iou: 0.0734 - iou_thresholded: 0.1810 - val_loss: 0.0025 - val_iou: 0.0235 - val_iou_thresholded: 0.7404
# Epoch 12/200
# 843/843 [==============================] - 382s 453ms/step - loss: 0.0017 - iou: 0.0890 - iou_thresholded: 0.2074 - val_loss: 0.0034 - val_iou: 0.0112 - val_iou_thresholded: 0.8245
# Epoch 13/200
# 843/843 [==============================] - 382s 453ms/step - loss: 0.0015 - iou: 0.1021 - iou_thresholded: 0.2201 - val_loss: 0.0041 - val_iou: 0.0171 - val_iou_thresholded: 0.3248
# Epoch 14/200
# 843/843 [==============================] - 384s 455ms/step - loss: 0.0014 - iou: 0.1117 - iou_thresholded: 0.2352 - val_loss: 0.0038 - val_iou: 0.0112 - val_iou_thresholded: 0.7122
# Epoch 15/200
# 843/843 [==============================] - 382s 453ms/step - loss: 0.0014 - iou: 0.1248 - iou_thresholded: 0.2617 - val_loss: 0.0034 - val_iou: 0.0168 - val_iou_thresholded: 0.8078
# Epoch 16/200
# 843/843 [==============================] - 382s 453ms/step - loss: 0.0012 - iou: 0.1467 - iou_thresholded: 0.2777 - val_loss: 0.0033 - val_iou: 0.0265 - val_iou_thresholded: 0.7915
# Epoch 17/200
# 843/843 [==============================] - 382s 453ms/step - loss: 0.0011 - iou: 0.1726 - iou_thresholded: 0.3148 - val_loss: 0.0041 - val_iou: 0.0120 - val_iou_thresholded: 0.6752
# Epoch 18/200
# 843/843 [==============================] - 382s 453ms/step - loss: 0.0012 - iou: 0.1603 - iou_thresholded: 0.3079 - val_loss: 0.0027 - val_iou: 0.0258 - val_iou_thresholded: 0.6813
# Epoch 19/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.8694e-04 - iou: 0.2214 - iou_thresholded: 0.3828 - val_loss: 0.0034 - val_iou: 0.0324 - val_iou_thresholded: 0.7245
# Epoch 20/200
# 843/843 [==============================] - 382s 453ms/step - loss: 7.9782e-04 - iou: 0.2486 - iou_thresholded: 0.4137 - val_loss: 0.0036 - val_iou: 0.0542 - val_iou_thresholded: 0.7742
# Epoch 21/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.3695e-04 - iou: 0.2480 - iou_thresholded: 0.4186 - val_loss: 0.0040 - val_iou: 0.0284 - val_iou_thresholded: 0.7757
# Epoch 22/200
# 843/843 [==============================] - 382s 454ms/step - loss: 6.9775e-04 - iou: 0.2871 - iou_thresholded: 0.4701 - val_loss: 0.0043 - val_iou: 0.0407 - val_iou_thresholded: 0.7844
# Epoch 23/200
# 843/843 [==============================] - 383s 454ms/step - loss: 6.4921e-04 - iou: 0.3139 - iou_thresholded: 0.4976 - val_loss: 0.0038 - val_iou: 0.0464 - val_iou_thresholded: 0.6106
# Epoch 24/200
# 843/843 [==============================] - 382s 454ms/step - loss: 6.1797e-04 - iou: 0.3296 - iou_thresholded: 0.5079 - val_loss: 0.0040 - val_iou: 0.0556 - val_iou_thresholded: 0.7196
# Epoch 25/200
# 843/843 [==============================] - 382s 453ms/step - loss: 6.4604e-04 - iou: 0.3216 - iou_thresholded: 0.4944 - val_loss: 0.0051 - val_iou: 0.0541 - val_iou_thresholded: 0.7545
# Epoch 26/200
# 843/843 [==============================] - 382s 454ms/step - loss: 5.4671e-04 - iou: 0.3745 - iou_thresholded: 0.5528 - val_loss: 0.0049 - val_iou: 0.0372 - val_iou_thresholded: 0.5381
# Epoch 27/200
# 843/843 [==============================] - 382s 453ms/step - loss: 5.9946e-04 - iou: 0.3617 - iou_thresholded: 0.5448 - val_loss: 0.0042 - val_iou: 0.0492 - val_iou_thresholded: 0.7227
# Epoch 28/200
# 843/843 [==============================] - 382s 453ms/step - loss: 5.1616e-04 - iou: 0.4000 - iou_thresholded: 0.5735 - val_loss: 0.0043 - val_iou: 0.0622 - val_iou_thresholded: 0.7054
# Epoch 29/200
# 843/843 [==============================] - 382s 453ms/step - loss: 5.2638e-04 - iou: 0.3931 - iou_thresholded: 0.5772 - val_loss: 0.0036 - val_iou: 0.0541 - val_iou_thresholded: 0.6911
# Epoch 30/200
# 843/843 [==============================] - 382s 453ms/step - loss: 4.3826e-04 - iou: 0.4330 - iou_thresholded: 0.6211 - val_loss: 0.0044 - val_iou: 0.0728 - val_iou_thresholded: 0.6980
# Epoch 31/200
# 843/843 [==============================] - 382s 453ms/step - loss: 4.5365e-04 - iou: 0.4442 - iou_thresholded: 0.6227 - val_loss: 0.0052 - val_iou: 0.0717 - val_iou_thresholded: 0.7238
# Epoch 32/200
# 843/843 [==============================] - 382s 453ms/step - loss: 4.8505e-04 - iou: 0.4327 - iou_thresholded: 0.6160 - val_loss: 0.0051 - val_iou: 0.0844 - val_iou_thresholded: 0.7550
# Epoch 33/200
# 843/843 [==============================] - 382s 453ms/step - loss: 4.1262e-04 - iou: 0.4719 - iou_thresholded: 0.6451 - val_loss: 0.0043 - val_iou: 0.0787 - val_iou_thresholded: 0.7349
# Epoch 34/200
# 843/843 [==============================] - 382s 453ms/step - loss: 3.8917e-04 - iou: 0.4826 - iou_thresholded: 0.6563 - val_loss: 0.0053 - val_iou: 0.0876 - val_iou_thresholded: 0.7380
# Epoch 35/200
# 843/843 [==============================] - 383s 454ms/step - loss: 3.9489e-04 - iou: 0.4866 - iou_thresholded: 0.6600 - val_loss: 0.0053 - val_iou: 0.0692 - val_iou_thresholded: 0.7179
# Epoch 36/200
# 843/843 [==============================] - 383s 454ms/step - loss: 3.7743e-04 - iou: 0.5007 - iou_thresholded: 0.6854 - val_loss: 0.0051 - val_iou: 0.0954 - val_iou_thresholded: 0.7148
# Epoch 37/200
# 843/843 [==============================] - 383s 454ms/step - loss: 4.2930e-04 - iou: 0.4786 - iou_thresholded: 0.6483 - val_loss: 0.0058 - val_iou: 0.0955 - val_iou_thresholded: 0.7807
# Epoch 38/200
# 843/843 [==============================] - 382s 453ms/step - loss: 3.3303e-04 - iou: 0.5196 - iou_thresholded: 0.6962 - val_loss: 0.0055 - val_iou: 0.0970 - val_iou_thresholded: 0.7261
# Epoch 39/200
# 843/843 [==============================] - 382s 453ms/step - loss: 4.4193e-04 - iou: 0.4791 - iou_thresholded: 0.6605 - val_loss: 0.0054 - val_iou: 0.0630 - val_iou_thresholded: 0.8133
# Epoch 40/200
# 843/843 [==============================] - 382s 454ms/step - loss: 3.4792e-04 - iou: 0.5310 - iou_thresholded: 0.7134 - val_loss: 0.0050 - val_iou: 0.0896 - val_iou_thresholded: 0.7557
# Epoch 41/200
# 843/843 [==============================] - 382s 454ms/step - loss: 3.3236e-04 - iou: 0.5356 - iou_thresholded: 0.7166 - val_loss: 0.0044 - val_iou: 0.0901 - val_iou_thresholded: 0.7003
# Epoch 42/200
# 843/843 [==============================] - 382s 454ms/step - loss: 3.3682e-04 - iou: 0.5297 - iou_thresholded: 0.6951 - val_loss: 0.0052 - val_iou: 0.1307 - val_iou_thresholded: 0.7669
# Epoch 43/200
# 843/843 [==============================] - 382s 453ms/step - loss: 3.3175e-04 - iou: 0.5364 - iou_thresholded: 0.7168 - val_loss: 0.0050 - val_iou: 0.0672 - val_iou_thresholded: 0.7176
# Epoch 44/200
# 843/843 [==============================] - 382s 453ms/step - loss: 3.1190e-04 - iou: 0.5594 - iou_thresholded: 0.7281 - val_loss: 0.0048 - val_iou: 0.1221 - val_iou_thresholded: 0.7390
# Epoch 45/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.9115e-04 - iou: 0.5710 - iou_thresholded: 0.7392 - val_loss: 0.0057 - val_iou: 0.1256 - val_iou_thresholded: 0.7323
# Epoch 46/200
# 843/843 [==============================] - 382s 453ms/step - loss: 4.2416e-04 - iou: 0.5173 - iou_thresholded: 0.6798 - val_loss: 0.0049 - val_iou: 0.0732 - val_iou_thresholded: 0.7959
# Epoch 47/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.8796e-04 - iou: 0.5743 - iou_thresholded: 0.7387 - val_loss: 0.0051 - val_iou: 0.1397 - val_iou_thresholded: 0.7247
# Epoch 48/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.8310e-04 - iou: 0.6034 - iou_thresholded: 0.7554 - val_loss: 0.0050 - val_iou: 0.1519 - val_iou_thresholded: 0.7739
# Epoch 49/200
# 843/843 [==============================] - 382s 453ms/step - loss: 3.2449e-04 - iou: 0.5681 - iou_thresholded: 0.7411 - val_loss: 0.0059 - val_iou: 0.1393 - val_iou_thresholded: 0.7487
# Epoch 50/200
# 843/843 [==============================] - 382s 453ms/step - loss: 3.2826e-04 - iou: 0.5822 - iou_thresholded: 0.7385 - val_loss: 0.0049 - val_iou: 0.1277 - val_iou_thresholded: 0.7697
# Epoch 51/200
# 843/843 [==============================] - 382s 454ms/step - loss: 2.8460e-04 - iou: 0.5899 - iou_thresholded: 0.7522 - val_loss: 0.0054 - val_iou: 0.1506 - val_iou_thresholded: 0.7685
# Epoch 52/200
# 843/843 [==============================] - 383s 454ms/step - loss: 2.7192e-04 - iou: 0.6167 - iou_thresholded: 0.7638 - val_loss: 0.0073 - val_iou: 0.0818 - val_iou_thresholded: 0.6923
# Epoch 53/200
# 843/843 [==============================] - 382s 454ms/step - loss: 2.5176e-04 - iou: 0.6152 - iou_thresholded: 0.7605 - val_loss: 0.0058 - val_iou: 0.0866 - val_iou_thresholded: 0.6661
# Epoch 54/200
# 843/843 [==============================] - 383s 454ms/step - loss: 2.6902e-04 - iou: 0.6091 - iou_thresholded: 0.7745 - val_loss: 0.0053 - val_iou: 0.1432 - val_iou_thresholded: 0.7742
# Epoch 55/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.8165e-04 - iou: 0.5928 - iou_thresholded: 0.7639 - val_loss: 0.0053 - val_iou: 0.1345 - val_iou_thresholded: 0.7693
# Epoch 56/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.3657e-04 - iou: 0.6236 - iou_thresholded: 0.7796 - val_loss: 0.0049 - val_iou: 0.1519 - val_iou_thresholded: 0.7432
# Epoch 57/200
# 843/843 [==============================] - 382s 454ms/step - loss: 2.3580e-04 - iou: 0.6312 - iou_thresholded: 0.7844 - val_loss: 0.0052 - val_iou: 0.1560 - val_iou_thresholded: 0.7039
# Epoch 58/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.3447e-04 - iou: 0.6344 - iou_thresholded: 0.7829 - val_loss: 0.0061 - val_iou: 0.2117 - val_iou_thresholded: 0.7337
# Epoch 59/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.5318e-04 - iou: 0.6440 - iou_thresholded: 0.7895 - val_loss: 0.0068 - val_iou: 0.2361 - val_iou_thresholded: 0.7867
# Epoch 60/200
# 843/843 [==============================] - 381s 453ms/step - loss: 2.7300e-04 - iou: 0.6226 - iou_thresholded: 0.7592 - val_loss: 0.0047 - val_iou: 0.1143 - val_iou_thresholded: 0.6965
# Epoch 61/200
# 843/843 [==============================] - 382s 454ms/step - loss: 2.3229e-04 - iou: 0.6308 - iou_thresholded: 0.7931 - val_loss: 0.0051 - val_iou: 0.1310 - val_iou_thresholded: 0.6565
# Epoch 62/200
# 843/843 [==============================] - 382s 453ms/step - loss: 3.2731e-04 - iou: 0.5763 - iou_thresholded: 0.7412 - val_loss: 0.0053 - val_iou: 0.1457 - val_iou_thresholded: 0.7362
# Epoch 63/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.3556e-04 - iou: 0.6313 - iou_thresholded: 0.7834 - val_loss: 0.0055 - val_iou: 0.2057 - val_iou_thresholded: 0.7494
# Epoch 64/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.9962e-04 - iou: 0.6572 - iou_thresholded: 0.8122 - val_loss: 0.0062 - val_iou: 0.2221 - val_iou_thresholded: 0.7809
# Epoch 65/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.1767e-04 - iou: 0.6569 - iou_thresholded: 0.7979 - val_loss: 0.0060 - val_iou: 0.2136 - val_iou_thresholded: 0.7667
# Epoch 66/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.2183e-04 - iou: 0.6564 - iou_thresholded: 0.7984 - val_loss: 0.0057 - val_iou: 0.1758 - val_iou_thresholded: 0.7189
# Epoch 67/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.9646e-04 - iou: 0.6705 - iou_thresholded: 0.8112 - val_loss: 0.0057 - val_iou: 0.2566 - val_iou_thresholded: 0.7619
# Epoch 68/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.9892e-04 - iou: 0.6867 - iou_thresholded: 0.8206 - val_loss: 0.0058 - val_iou: 0.2231 - val_iou_thresholded: 0.7470
# Epoch 69/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.2860e-04 - iou: 0.6575 - iou_thresholded: 0.8035 - val_loss: 0.0058 - val_iou: 0.1909 - val_iou_thresholded: 0.7639
# Epoch 70/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.9849e-04 - iou: 0.6656 - iou_thresholded: 0.8150 - val_loss: 0.0062 - val_iou: 0.2061 - val_iou_thresholded: 0.6843
# Epoch 71/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.1941e-04 - iou: 0.6689 - iou_thresholded: 0.8103 - val_loss: 0.0058 - val_iou: 0.1590 - val_iou_thresholded: 0.7022
# Epoch 72/200
# 843/843 [==============================] - 383s 454ms/step - loss: 2.1580e-04 - iou: 0.6661 - iou_thresholded: 0.8136 - val_loss: 0.0056 - val_iou: 0.2210 - val_iou_thresholded: 0.7558
# Epoch 73/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.9483e-04 - iou: 0.6832 - iou_thresholded: 0.8227 - val_loss: 0.0048 - val_iou: 0.1125 - val_iou_thresholded: 0.7183
# Epoch 74/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.8570e-04 - iou: 0.6789 - iou_thresholded: 0.8043 - val_loss: 0.0052 - val_iou: 0.1838 - val_iou_thresholded: 0.7005
# Epoch 75/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.9913e-04 - iou: 0.6799 - iou_thresholded: 0.8170 - val_loss: 0.0054 - val_iou: 0.2045 - val_iou_thresholded: 0.7243
# Epoch 76/200
# 843/843 [==============================] - 382s 454ms/step - loss: 1.8526e-04 - iou: 0.7095 - iou_thresholded: 0.8379 - val_loss: 0.0058 - val_iou: 0.2737 - val_iou_thresholded: 0.7378
# Epoch 77/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.5725e-04 - iou: 0.7216 - iou_thresholded: 0.8483 - val_loss: 0.0064 - val_iou: 0.2733 - val_iou_thresholded: 0.7738
# Epoch 78/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.8313e-04 - iou: 0.6989 - iou_thresholded: 0.8256 - val_loss: 0.0063 - val_iou: 0.1939 - val_iou_thresholded: 0.7411
# Epoch 79/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.6706e-04 - iou: 0.7126 - iou_thresholded: 0.8399 - val_loss: 0.0063 - val_iou: 0.2556 - val_iou_thresholded: 0.7362
# Epoch 80/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.8129e-04 - iou: 0.7009 - iou_thresholded: 0.8292 - val_loss: 0.0055 - val_iou: 0.2569 - val_iou_thresholded: 0.7555
# Epoch 81/200
# 843/843 [==============================] - 382s 453ms/step - loss: 2.1253e-04 - iou: 0.6804 - iou_thresholded: 0.8166 - val_loss: 0.0052 - val_iou: 0.1900 - val_iou_thresholded: 0.7118
# Epoch 82/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.5369e-04 - iou: 0.7143 - iou_thresholded: 0.8505 - val_loss: 0.0065 - val_iou: 0.2955 - val_iou_thresholded: 0.7590
# Epoch 83/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.9141e-04 - iou: 0.7039 - iou_thresholded: 0.8350 - val_loss: 0.0057 - val_iou: 0.2560 - val_iou_thresholded: 0.7076
# Epoch 84/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.6754e-04 - iou: 0.7053 - iou_thresholded: 0.8424 - val_loss: 0.0059 - val_iou: 0.2227 - val_iou_thresholded: 0.7504
# Epoch 85/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.6472e-04 - iou: 0.7296 - iou_thresholded: 0.8513 - val_loss: 0.0061 - val_iou: 0.2669 - val_iou_thresholded: 0.7141
# Epoch 86/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.7798e-04 - iou: 0.7137 - iou_thresholded: 0.8382 - val_loss: 0.0060 - val_iou: 0.2329 - val_iou_thresholded: 0.7091
# Epoch 87/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.4106e-04 - iou: 0.7401 - iou_thresholded: 0.8615 - val_loss: 0.0066 - val_iou: 0.3324 - val_iou_thresholded: 0.7542
# Epoch 88/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.6298e-04 - iou: 0.7262 - iou_thresholded: 0.8431 - val_loss: 0.0059 - val_iou: 0.2838 - val_iou_thresholded: 0.7208
# Epoch 89/200
# 843/843 [==============================] - 383s 455ms/step - loss: 1.6066e-04 - iou: 0.7283 - iou_thresholded: 0.8471 - val_loss: 0.0057 - val_iou: 0.2887 - val_iou_thresholded: 0.7329
# Epoch 90/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.6652e-04 - iou: 0.7130 - iou_thresholded: 0.8473 - val_loss: 0.0053 - val_iou: 0.2767 - val_iou_thresholded: 0.7342
# Epoch 91/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.5444e-04 - iou: 0.7260 - iou_thresholded: 0.8493 - val_loss: 0.0061 - val_iou: 0.3010 - val_iou_thresholded: 0.7316
# Epoch 92/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.5724e-04 - iou: 0.7408 - iou_thresholded: 0.8597 - val_loss: 0.0057 - val_iou: 0.2724 - val_iou_thresholded: 0.7586
# Epoch 93/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.4172e-04 - iou: 0.7456 - iou_thresholded: 0.8687 - val_loss: 0.0062 - val_iou: 0.3845 - val_iou_thresholded: 0.7359
# Epoch 94/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.3381e-04 - iou: 0.7472 - iou_thresholded: 0.8616 - val_loss: 0.0066 - val_iou: 0.3257 - val_iou_thresholded: 0.7610
# Epoch 95/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.6080e-04 - iou: 0.7341 - iou_thresholded: 0.8559 - val_loss: 0.0058 - val_iou: 0.2983 - val_iou_thresholded: 0.7741
# Epoch 96/200
# 843/843 [==============================] - 383s 455ms/step - loss: 1.4495e-04 - iou: 0.7294 - iou_thresholded: 0.8518 - val_loss: 0.0065 - val_iou: 0.2974 - val_iou_thresholded: 0.7448
# Epoch 97/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.4003e-04 - iou: 0.7422 - iou_thresholded: 0.8664 - val_loss: 0.0061 - val_iou: 0.3206 - val_iou_thresholded: 0.7382
# Epoch 98/200
# 843/843 [==============================] - 383s 455ms/step - loss: 1.4813e-04 - iou: 0.7430 - iou_thresholded: 0.8542 - val_loss: 0.0065 - val_iou: 0.3063 - val_iou_thresholded: 0.7523
# Epoch 99/200
# 843/843 [==============================] - 383s 455ms/step - loss: 1.4227e-04 - iou: 0.7527 - iou_thresholded: 0.8658 - val_loss: 0.0062 - val_iou: 0.3582 - val_iou_thresholded: 0.7666
# Epoch 100/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.3026e-04 - iou: 0.7497 - iou_thresholded: 0.8700 - val_loss: 0.0057 - val_iou: 0.3129 - val_iou_thresholded: 0.7281
# Epoch 101/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.3270e-04 - iou: 0.7683 - iou_thresholded: 0.8750 - val_loss: 0.0064 - val_iou: 0.3837 - val_iou_thresholded: 0.7636
# Epoch 102/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.3586e-04 - iou: 0.7640 - iou_thresholded: 0.8698 - val_loss: 0.0063 - val_iou: 0.3856 - val_iou_thresholded: 0.7653
# Epoch 103/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.6060e-04 - iou: 0.7430 - iou_thresholded: 0.8601 - val_loss: 0.0064 - val_iou: 0.3067 - val_iou_thresholded: 0.7352
# Epoch 104/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.3012e-04 - iou: 0.7623 - iou_thresholded: 0.8831 - val_loss: 0.0071 - val_iou: 0.3439 - val_iou_thresholded: 0.7316
# Epoch 105/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.2529e-04 - iou: 0.7756 - iou_thresholded: 0.8817 - val_loss: 0.0060 - val_iou: 0.2357 - val_iou_thresholded: 0.6565
# Epoch 106/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.4239e-04 - iou: 0.7700 - iou_thresholded: 0.8719 - val_loss: 0.0064 - val_iou: 0.2854 - val_iou_thresholded: 0.7291
# Epoch 107/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.3573e-04 - iou: 0.7664 - iou_thresholded: 0.8744 - val_loss: 0.0063 - val_iou: 0.3453 - val_iou_thresholded: 0.7450
# Epoch 108/200
# 843/843 [==============================] - 382s 454ms/step - loss: 1.2219e-04 - iou: 0.7741 - iou_thresholded: 0.8767 - val_loss: 0.0067 - val_iou: 0.3840 - val_iou_thresholded: 0.7548
# Epoch 109/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.2655e-04 - iou: 0.7664 - iou_thresholded: 0.8826 - val_loss: 0.0064 - val_iou: 0.3719 - val_iou_thresholded: 0.7505
# Epoch 110/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.6203e-04 - iou: 0.7352 - iou_thresholded: 0.8579 - val_loss: 0.0059 - val_iou: 0.2879 - val_iou_thresholded: 0.7600
# Epoch 111/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.4138e-04 - iou: 0.7477 - iou_thresholded: 0.8638 - val_loss: 0.0059 - val_iou: 0.3128 - val_iou_thresholded: 0.7355
# Epoch 112/200
# 843/843 [==============================] - 383s 455ms/step - loss: 1.2158e-04 - iou: 0.7747 - iou_thresholded: 0.8826 - val_loss: 0.0063 - val_iou: 0.3907 - val_iou_thresholded: 0.7289
# Epoch 113/200
# 843/843 [==============================] - 383s 455ms/step - loss: 1.2172e-04 - iou: 0.7715 - iou_thresholded: 0.8776 - val_loss: 0.0062 - val_iou: 0.3983 - val_iou_thresholded: 0.7494
# Epoch 114/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.2363e-04 - iou: 0.7864 - iou_thresholded: 0.8859 - val_loss: 0.0068 - val_iou: 0.4218 - val_iou_thresholded: 0.7743
# Epoch 115/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.1448e-04 - iou: 0.7860 - iou_thresholded: 0.8852 - val_loss: 0.0063 - val_iou: 0.4154 - val_iou_thresholded: 0.7498
# Epoch 116/200
# 843/843 [==============================] - 384s 456ms/step - loss: 1.2458e-04 - iou: 0.7904 - iou_thresholded: 0.8859 - val_loss: 0.0057 - val_iou: 0.4106 - val_iou_thresholded: 0.7629
# Epoch 117/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.1713e-04 - iou: 0.7901 - iou_thresholded: 0.8910 - val_loss: 0.0069 - val_iou: 0.3785 - val_iou_thresholded: 0.7668
# Epoch 118/200
# 843/843 [==============================] - 384s 456ms/step - loss: 1.1324e-04 - iou: 0.7997 - iou_thresholded: 0.8960 - val_loss: 0.0070 - val_iou: 0.4397 - val_iou_thresholded: 0.7656
# Epoch 119/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.2828e-04 - iou: 0.7906 - iou_thresholded: 0.8870 - val_loss: 0.0068 - val_iou: 0.4106 - val_iou_thresholded: 0.7710
# Epoch 120/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.1674e-04 - iou: 0.7882 - iou_thresholded: 0.8887 - val_loss: 0.0060 - val_iou: 0.4031 - val_iou_thresholded: 0.7438
# Epoch 121/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.1202e-04 - iou: 0.7934 - iou_thresholded: 0.8949 - val_loss: 0.0068 - val_iou: 0.4793 - val_iou_thresholded: 0.7632
# Epoch 122/200
# 843/843 [==============================] - 385s 456ms/step - loss: 1.0292e-04 - iou: 0.7927 - iou_thresholded: 0.8946 - val_loss: 0.0064 - val_iou: 0.4672 - val_iou_thresholded: 0.7501
# Epoch 123/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.1698e-04 - iou: 0.7952 - iou_thresholded: 0.8794 - val_loss: 0.0071 - val_iou: 0.4739 - val_iou_thresholded: 0.7613
# Epoch 124/200
# 843/843 [==============================] - 384s 456ms/step - loss: 1.1648e-04 - iou: 0.8031 - iou_thresholded: 0.8931 - val_loss: 0.0072 - val_iou: 0.4627 - val_iou_thresholded: 0.7797
# Epoch 125/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.1897e-04 - iou: 0.7833 - iou_thresholded: 0.8910 - val_loss: 0.0068 - val_iou: 0.4286 - val_iou_thresholded: 0.7434
# Epoch 126/200
# 843/843 [==============================] - 384s 456ms/step - loss: 1.0810e-04 - iou: 0.8056 - iou_thresholded: 0.9000 - val_loss: 0.0062 - val_iou: 0.3234 - val_iou_thresholded: 0.7511
# Epoch 127/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.1374e-04 - iou: 0.8020 - iou_thresholded: 0.8920 - val_loss: 0.0070 - val_iou: 0.3833 - val_iou_thresholded: 0.7492
# Epoch 128/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.0703e-04 - iou: 0.7994 - iou_thresholded: 0.8936 - val_loss: 0.0073 - val_iou: 0.4381 - val_iou_thresholded: 0.7758
# Epoch 129/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.0207e-04 - iou: 0.8147 - iou_thresholded: 0.8994 - val_loss: 0.0063 - val_iou: 0.4589 - val_iou_thresholded: 0.7520
# Epoch 130/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.1424e-04 - iou: 0.7993 - iou_thresholded: 0.8942 - val_loss: 0.0066 - val_iou: 0.4825 - val_iou_thresholded: 0.7562
# Epoch 131/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.6508e-05 - iou: 0.8152 - iou_thresholded: 0.9055 - val_loss: 0.0067 - val_iou: 0.4538 - val_iou_thresholded: 0.7515
# Epoch 132/200
# 843/843 [==============================] - 382s 454ms/step - loss: 1.0322e-04 - iou: 0.8161 - iou_thresholded: 0.9020 - val_loss: 0.0065 - val_iou: 0.4758 - val_iou_thresholded: 0.7661
# Epoch 133/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.0187e-04 - iou: 0.8120 - iou_thresholded: 0.9016 - val_loss: 0.0070 - val_iou: 0.5255 - val_iou_thresholded: 0.7726
# Epoch 134/200
# 843/843 [==============================] - 382s 454ms/step - loss: 1.1263e-04 - iou: 0.8139 - iou_thresholded: 0.8959 - val_loss: 0.0067 - val_iou: 0.4901 - val_iou_thresholded: 0.7623
# Epoch 135/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.0771e-04 - iou: 0.8157 - iou_thresholded: 0.8962 - val_loss: 0.0072 - val_iou: 0.4451 - val_iou_thresholded: 0.7605
# Epoch 136/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.0195e-04 - iou: 0.8069 - iou_thresholded: 0.9014 - val_loss: 0.0072 - val_iou: 0.4723 - val_iou_thresholded: 0.7811
# Epoch 137/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.1688e-04 - iou: 0.7942 - iou_thresholded: 0.8915 - val_loss: 0.0061 - val_iou: 0.4357 - val_iou_thresholded: 0.7412
# Epoch 138/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.0247e-04 - iou: 0.8121 - iou_thresholded: 0.8967 - val_loss: 0.0069 - val_iou: 0.4504 - val_iou_thresholded: 0.7638
# Epoch 139/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.1149e-04 - iou: 0.8162 - iou_thresholded: 0.9028 - val_loss: 0.0063 - val_iou: 0.4128 - val_iou_thresholded: 0.7308
# Epoch 140/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.0724e-04 - iou: 0.8089 - iou_thresholded: 0.9005 - val_loss: 0.0079 - val_iou: 0.4256 - val_iou_thresholded: 0.7791
# Epoch 141/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.0327e-04 - iou: 0.8096 - iou_thresholded: 0.9037 - val_loss: 0.0070 - val_iou: 0.4348 - val_iou_thresholded: 0.7708
# Epoch 142/200
# 843/843 [==============================] - 384s 456ms/step - loss: 9.3399e-05 - iou: 0.8044 - iou_thresholded: 0.9045 - val_loss: 0.0064 - val_iou: 0.4400 - val_iou_thresholded: 0.7520
# Epoch 143/200
# 843/843 [==============================] - 384s 456ms/step - loss: 1.0538e-04 - iou: 0.8168 - iou_thresholded: 0.9030 - val_loss: 0.0069 - val_iou: 0.4368 - val_iou_thresholded: 0.7657
# Epoch 144/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.0300e-04 - iou: 0.8137 - iou_thresholded: 0.9013 - val_loss: 0.0067 - val_iou: 0.4891 - val_iou_thresholded: 0.7889
# Epoch 145/200
# 843/843 [==============================] - 384s 456ms/step - loss: 1.0971e-04 - iou: 0.8023 - iou_thresholded: 0.8956 - val_loss: 0.0068 - val_iou: 0.4679 - val_iou_thresholded: 0.7856
# Epoch 146/200
# 843/843 [==============================] - 384s 455ms/step - loss: 9.7708e-05 - iou: 0.8177 - iou_thresholded: 0.9058 - val_loss: 0.0072 - val_iou: 0.4659 - val_iou_thresholded: 0.7880
# Epoch 147/200
# 843/843 [==============================] - 384s 456ms/step - loss: 9.4491e-05 - iou: 0.8341 - iou_thresholded: 0.9153 - val_loss: 0.0073 - val_iou: 0.4778 - val_iou_thresholded: 0.7793
# Epoch 148/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.2268e-05 - iou: 0.8251 - iou_thresholded: 0.9121 - val_loss: 0.0065 - val_iou: 0.4607 - val_iou_thresholded: 0.7398
# Epoch 149/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.7880e-05 - iou: 0.8115 - iou_thresholded: 0.8986 - val_loss: 0.0077 - val_iou: 0.5267 - val_iou_thresholded: 0.7642
# Epoch 150/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.1235e-04 - iou: 0.8174 - iou_thresholded: 0.9046 - val_loss: 0.0067 - val_iou: 0.4232 - val_iou_thresholded: 0.7527
# Epoch 151/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.4260e-05 - iou: 0.8205 - iou_thresholded: 0.9095 - val_loss: 0.0071 - val_iou: 0.4866 - val_iou_thresholded: 0.7598
# Epoch 152/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.9135e-05 - iou: 0.8302 - iou_thresholded: 0.9153 - val_loss: 0.0073 - val_iou: 0.5343 - val_iou_thresholded: 0.7831
# Epoch 153/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.6293e-05 - iou: 0.8330 - iou_thresholded: 0.9062 - val_loss: 0.0070 - val_iou: 0.5050 - val_iou_thresholded: 0.7475
# Epoch 154/200
# 843/843 [==============================] - 382s 454ms/step - loss: 1.0342e-04 - iou: 0.8085 - iou_thresholded: 0.9031 - val_loss: 0.0063 - val_iou: 0.4487 - val_iou_thresholded: 0.7331
# Epoch 155/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.9901e-05 - iou: 0.8113 - iou_thresholded: 0.9056 - val_loss: 0.0073 - val_iou: 0.4428 - val_iou_thresholded: 0.7429
# Epoch 156/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.1694e-05 - iou: 0.8324 - iou_thresholded: 0.9141 - val_loss: 0.0071 - val_iou: 0.5306 - val_iou_thresholded: 0.7825
# Epoch 157/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.8896e-05 - iou: 0.8340 - iou_thresholded: 0.9149 - val_loss: 0.0075 - val_iou: 0.4335 - val_iou_thresholded: 0.7735
# Epoch 158/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.0028e-04 - iou: 0.8227 - iou_thresholded: 0.9114 - val_loss: 0.0068 - val_iou: 0.4622 - val_iou_thresholded: 0.7547
# Epoch 159/200
# 843/843 [==============================] - 383s 454ms/step - loss: 8.9284e-05 - iou: 0.8333 - iou_thresholded: 0.9167 - val_loss: 0.0066 - val_iou: 0.4789 - val_iou_thresholded: 0.7743
# Epoch 160/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.4407e-05 - iou: 0.8283 - iou_thresholded: 0.9161 - val_loss: 0.0062 - val_iou: 0.4392 - val_iou_thresholded: 0.7514
# Epoch 161/200
# 843/843 [==============================] - 383s 454ms/step - loss: 1.0683e-04 - iou: 0.8066 - iou_thresholded: 0.9005 - val_loss: 0.0072 - val_iou: 0.4812 - val_iou_thresholded: 0.7606
# Epoch 162/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.0139e-04 - iou: 0.8230 - iou_thresholded: 0.9040 - val_loss: 0.0066 - val_iou: 0.4560 - val_iou_thresholded: 0.7496
# Epoch 163/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.7310e-05 - iou: 0.8327 - iou_thresholded: 0.9108 - val_loss: 0.0065 - val_iou: 0.4916 - val_iou_thresholded: 0.7643
# Epoch 164/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.7930e-05 - iou: 0.8357 - iou_thresholded: 0.9129 - val_loss: 0.0071 - val_iou: 0.5070 - val_iou_thresholded: 0.7806
# Epoch 165/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.0590e-04 - iou: 0.8080 - iou_thresholded: 0.9029 - val_loss: 0.0070 - val_iou: 0.4839 - val_iou_thresholded: 0.7614
# Epoch 166/200
# 843/843 [==============================] - 383s 455ms/step - loss: 9.0764e-05 - iou: 0.8209 - iou_thresholded: 0.9055 - val_loss: 0.0064 - val_iou: 0.4765 - val_iou_thresholded: 0.7606
# Epoch 167/200
# 843/843 [==============================] - 384s 455ms/step - loss: 9.4091e-05 - iou: 0.8353 - iou_thresholded: 0.9115 - val_loss: 0.0069 - val_iou: 0.5394 - val_iou_thresholded: 0.7662
# Epoch 168/200
# 843/843 [==============================] - 384s 455ms/step - loss: 1.1685e-04 - iou: 0.8155 - iou_thresholded: 0.9042 - val_loss: 0.0065 - val_iou: 0.4988 - val_iou_thresholded: 0.7600
# Epoch 169/200
# 843/843 [==============================] - 384s 455ms/step - loss: 8.9610e-05 - iou: 0.8307 - iou_thresholded: 0.9130 - val_loss: 0.0064 - val_iou: 0.4833 - val_iou_thresholded: 0.7597
# Epoch 170/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.0419e-05 - iou: 0.8382 - iou_thresholded: 0.9147 - val_loss: 0.0068 - val_iou: 0.4956 - val_iou_thresholded: 0.7578
# Epoch 171/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.3222e-05 - iou: 0.8338 - iou_thresholded: 0.9146 - val_loss: 0.0068 - val_iou: 0.5178 - val_iou_thresholded: 0.7454
# Epoch 172/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.4868e-05 - iou: 0.8367 - iou_thresholded: 0.9197 - val_loss: 0.0068 - val_iou: 0.4280 - val_iou_thresholded: 0.7390
# Epoch 173/200
# 843/843 [==============================] - 382s 453ms/step - loss: 1.0220e-04 - iou: 0.8038 - iou_thresholded: 0.9045 - val_loss: 0.0064 - val_iou: 0.4570 - val_iou_thresholded: 0.7563
# Epoch 174/200
# 843/843 [==============================] - 383s 454ms/step - loss: 8.7169e-05 - iou: 0.8383 - iou_thresholded: 0.9213 - val_loss: 0.0067 - val_iou: 0.5148 - val_iou_thresholded: 0.7532
# Epoch 175/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.1226e-05 - iou: 0.8352 - iou_thresholded: 0.9143 - val_loss: 0.0067 - val_iou: 0.4998 - val_iou_thresholded: 0.7422
# Epoch 176/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.5580e-05 - iou: 0.8439 - iou_thresholded: 0.9213 - val_loss: 0.0062 - val_iou: 0.4611 - val_iou_thresholded: 0.7346
# Epoch 177/200
# 843/843 [==============================] - 383s 454ms/step - loss: 8.5984e-05 - iou: 0.8431 - iou_thresholded: 0.9182 - val_loss: 0.0068 - val_iou: 0.4936 - val_iou_thresholded: 0.7325
# Epoch 178/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.3327e-05 - iou: 0.8514 - iou_thresholded: 0.9210 - val_loss: 0.0073 - val_iou: 0.5545 - val_iou_thresholded: 0.7750
# Epoch 179/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.3628e-05 - iou: 0.8474 - iou_thresholded: 0.9211 - val_loss: 0.0068 - val_iou: 0.5688 - val_iou_thresholded: 0.7699
# Epoch 180/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.3243e-05 - iou: 0.8528 - iou_thresholded: 0.9197 - val_loss: 0.0072 - val_iou: 0.5751 - val_iou_thresholded: 0.7623
# Epoch 181/200
# 843/843 [==============================] - 382s 454ms/step - loss: 9.2171e-05 - iou: 0.8535 - iou_thresholded: 0.9238 - val_loss: 0.0068 - val_iou: 0.5197 - val_iou_thresholded: 0.7563
# Epoch 182/200
# 843/843 [==============================] - 382s 454ms/step - loss: 9.3999e-05 - iou: 0.8233 - iou_thresholded: 0.9073 - val_loss: 0.0074 - val_iou: 0.4597 - val_iou_thresholded: 0.7879
# Epoch 183/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.6243e-05 - iou: 0.8270 - iou_thresholded: 0.9182 - val_loss: 0.0070 - val_iou: 0.5179 - val_iou_thresholded: 0.7644
# Epoch 184/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.6880e-05 - iou: 0.8426 - iou_thresholded: 0.9196 - val_loss: 0.0070 - val_iou: 0.4991 - val_iou_thresholded: 0.7534
# Epoch 185/200
# 843/843 [==============================] - 382s 453ms/step - loss: 7.3128e-05 - iou: 0.8506 - iou_thresholded: 0.9244 - val_loss: 0.0076 - val_iou: 0.5701 - val_iou_thresholded: 0.7645
# Epoch 186/200
# 843/843 [==============================] - 383s 454ms/step - loss: 7.5653e-05 - iou: 0.8609 - iou_thresholded: 0.9281 - val_loss: 0.0073 - val_iou: 0.5997 - val_iou_thresholded: 0.7623
# Epoch 187/200
# 843/843 [==============================] - 382s 453ms/step - loss: 9.4352e-05 - iou: 0.8482 - iou_thresholded: 0.9160 - val_loss: 0.0071 - val_iou: 0.4971 - val_iou_thresholded: 0.7385
# Epoch 188/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.3552e-05 - iou: 0.8530 - iou_thresholded: 0.9262 - val_loss: 0.0074 - val_iou: 0.5869 - val_iou_thresholded: 0.7697
# Epoch 189/200
# 843/843 [==============================] - 382s 453ms/step - loss: 7.2625e-05 - iou: 0.8514 - iou_thresholded: 0.9246 - val_loss: 0.0071 - val_iou: 0.5693 - val_iou_thresholded: 0.7677
# Epoch 190/200
# 843/843 [==============================] - 382s 454ms/step - loss: 8.0566e-05 - iou: 0.8563 - iou_thresholded: 0.9246 - val_loss: 0.0069 - val_iou: 0.5262 - val_iou_thresholded: 0.7554
# Epoch 191/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.7568e-05 - iou: 0.8432 - iou_thresholded: 0.9166 - val_loss: 0.0074 - val_iou: 0.5732 - val_iou_thresholded: 0.7755
# Epoch 192/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.1386e-05 - iou: 0.8561 - iou_thresholded: 0.9236 - val_loss: 0.0071 - val_iou: 0.5346 - val_iou_thresholded: 0.7539
# Epoch 193/200
# 843/843 [==============================] - 383s 454ms/step - loss: 8.1722e-05 - iou: 0.8441 - iou_thresholded: 0.9201 - val_loss: 0.0067 - val_iou: 0.5255 - val_iou_thresholded: 0.7436
# Epoch 194/200
# 843/843 [==============================] - 383s 454ms/step - loss: 8.3851e-05 - iou: 0.8549 - iou_thresholded: 0.9218 - val_loss: 0.0074 - val_iou: 0.5161 - val_iou_thresholded: 0.7415
# Epoch 195/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.7493e-05 - iou: 0.8401 - iou_thresholded: 0.9163 - val_loss: 0.0067 - val_iou: 0.4797 - val_iou_thresholded: 0.7403
# Epoch 196/200
# 843/843 [==============================] - 382s 453ms/step - loss: 8.2415e-05 - iou: 0.8542 - iou_thresholded: 0.9192 - val_loss: 0.0071 - val_iou: 0.5579 - val_iou_thresholded: 0.7533
# Epoch 197/200
# 843/843 [==============================] - 382s 453ms/step - loss: 7.5014e-05 - iou: 0.8617 - iou_thresholded: 0.9277 - val_loss: 0.0073 - val_iou: 0.5503 - val_iou_thresholded: 0.7648
# Epoch 198/200
# 843/843 [==============================] - 382s 453ms/step - loss: 7.5645e-05 - iou: 0.8643 - iou_thresholded: 0.9273 - val_loss: 0.0079 - val_iou: 0.6115 - val_iou_thresholded: 0.7904
# Epoch 199/200
# 843/843 [==============================] - 383s 454ms/step - loss: 7.6017e-05 - iou: 0.8600 - iou_thresholded: 0.9214 - val_loss: 0.0068 - val_iou: 0.4055 - val_iou_thresholded: 0.7347
# Epoch 200/200
# 843/843 [==============================] - 382s 453ms/step - loss: 7.4428e-05 - iou: 0.8666 - iou_thresholded: 0.9271 - val_loss: 0.0065 - val_iou: 0.4702 - val_iou_thresholded: 0.7111

# %%
C.Helper.visualize_graph(history)

# %%
model.save('/raid/mpsych/CACTAS/DATA/unet_model_v1.h5')

# %%
####### TEST using VASCUCAP GT ###########

# %%
DATAPATH='/raid/mpsych/CACTAS/DATA/ESUS'
VASCUPATH='/raid/mpsych/CACTAS/DATA/ELUCID'

# %%
images, labels = C.Helper.load_data(DATAPATH)
v_masks = C.Helper.load_seg_data(VASCUPATH)

# %%
matched_images = []
v_numbers = [filename.split(".")[0] for filename in v_masks]

# %%
for num in v_numbers:
    for img in images:
        if img.startswith(f"{num}.img") or img.startswith(f"{num}.b.img"):
            matched_images.append(img)

# %%
X_test = []
m_test = []

# %%
for file in matched_images:
    data, header = nrrd.read(DATAPATH + "/" +file)
    normalized_data = (data - np.min(data)) / (np.max(data) - np.min(data))
    X_test.append(normalized_data)

# %%
for file in v_masks:
    data, header = nrrd.read(VASCUPATH + "/" +file)
    normalized_data = (data - np.min(data)) / (np.max(data) - np.min(data))
    m_test.append(normalized_data)

# %%
len(X_test), len(m_test)
# Out:
# (27, 27)

# %%
# Image
slices_2 = []
for i in range(len(X_test)):
    for z in range(X_test[i].shape[2]):
        slice_2d = X_test[i][:, :, z]
        slices_2.append(slice_2d)
X_test_array = np.array(slices_2)

# %%
# Mask
slices_mtest=[]
for i in range(len(m_test)):
    for z in range(m_test[i].shape[2]):
        slice_2d = m_test[i][:, :, z]
        slices_mtest.append(slice_2d)
m_test_array = np.array(slices_mtest)

# %%
X_test_array = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1],X_test_array.shape[2], 1)
m_test_array = m_test_array.reshape(m_test_array.shape[0], m_test_array.shape[1],m_test_array.shape[2], 1)

# %%
print(X_test_array.shape, m_test_array.shape)
# Out:
# (6322, 512, 512, 1) (6322, 512, 512, 1)

# %%
# from tensorflow.keras.models import load_model
# model = load_model('/raid/mpsych/CACTAS/DATA/unet_model_v1.h5')

# %%
y_pred = C.Helper.prediction(X_test_array, model)

# %%
C.Helper.visualize_result(X_test_array, m_test_array, y_pred)

# %%
C.Helper.visualize_result_limit(X_test_array, m_test_array, y_pred, start_index=55, end_index=85)

# %%
C.Helper.evaluate(X_test_array, m_test_array, model)
# Out:
# 198/198 [==============================] - 55s 278ms/step - loss: 0.0013 - iou: 0.4393 - iou_thresholded: 0.7614
# (0.0012626921525225043, 0.43934738636016846, 0.7613536715507507)

# %%
a = y_pred
a_binary = np.zeros(a.shape, dtype=np.bool_)
a_binary[a > 0.5] = True

# %%
C.Helper.visualize_result_limit(X_test_array, m_test_array, a_binary, start_index=55, end_index=85)

# %%
C.Helper.evaluate(X_test_array, a_binary, model)
# Out:
# 198/198 [==============================] - 49s 250ms/step - loss: 2.8781e-05 - iou: 0.6236 - iou_thresholded: 1.0000
# (2.878103441616986e-05, 0.6235952377319336, 1.0)
