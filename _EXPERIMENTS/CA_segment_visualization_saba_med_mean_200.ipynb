# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from mpl_toolkits.mplot3d import Axes3D

from skimage import measure
from skimage.draw import ellipsoid
import cactas as C
import nrrd

# %%
DATAPATH1 = '/raid/mpsych/CACTAS/DATA/CA16/'
DATAPATH2 = '/raid/mpsych/CACTAS/DATA/CA17/'

# %%
DATAPATHS = [DATAPATH1, DATAPATH2]

# %%
TITLES = ["saba-median", "saba-mean"]

# %%
segs = [C.Helper.load_seg_data(DATAPATH) for DATAPATH in DATAPATHS]

# %%
for i in range(len(segs[0])):
    fig = plt.figure(figsize=(15, 5))

    for j, seg_list in enumerate(segs):
        d = DATAPATHS[j] + seg_list[i]
        data, header = nrrd.read(d)
        
        min_val, max_val = data.min(), data.max()
        isovalue = (min_val + max_val) / 2
        
        if isovalue != 0:
            vertices, faces, normals, values = measure.marching_cubes(data, isovalue)
            print(f"{seg_list[i]} from {TITLES[j]}")

            ax = fig.add_subplot(1, len(DATAPATHS), j+1, projection='3d')

            ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], color='black', s=10)
            mesh = Poly3DCollection(vertices[faces], linewidths=0.05, edgecolors='green', alpha=0.1)
            ax.add_collection3d(mesh)
            
            ax.view_init(elev=0, azim=90)
            ax.set_title(TITLES[j])

    plt.show()
# Out:
# 13.ca.seg.nrrd from saba-median
# 13.ca.seg.nrrd from saba-mean
# 55.ca.seg.nrrd from saba-median
# 55.ca.seg.nrrd from saba-mean
# 18.ca.seg.nrrd from saba-median
# 18.ca.seg.nrrd from saba-mean
# 47.ca.seg.nrrd from saba-median
# 47.ca.seg.nrrd from saba-mean
# 60.ca.seg.nrrd from saba-median
# 60.ca.seg.nrrd from saba-mean
# 35.ca.seg.nrrd from saba-median
# 35.ca.seg.nrrd from saba-mean
# 16.ca.seg.nrrd from saba-median
# 16.ca.seg.nrrd from saba-mean
# 33.ca.seg.nrrd from saba-median
# 33.ca.seg.nrrd from saba-mean
# 95.ca.seg.nrrd from saba-median
# 95.ca.seg.nrrd from saba-mean
# 61.ca.seg.nrrd from saba-median
# 61.ca.seg.nrrd from saba-mean
# 50.ca.seg.nrrd from saba-median
# 50.ca.seg.nrrd from saba-mean
# 7.ca.seg.nrrd from saba-median
# 7.ca.seg.nrrd from saba-mean
# 6.ca.seg.nrrd from saba-median
# 6.ca.seg.nrrd from saba-mean
# 39.ca.seg.nrrd from saba-median
# 39.ca.seg.nrrd from saba-mean
# 9.ca.seg.nrrd from saba-median
# 9.ca.seg.nrrd from saba-mean
# 2.ca.seg.nrrd from saba-median
# 2.ca.seg.nrrd from saba-mean
# 66.ca.seg.nrrd from saba-median
# 66.ca.seg.nrrd from saba-mean
# 17.ca.seg.nrrd from saba-median
# 17.ca.seg.nrrd from saba-mean
# 71.ca.seg.nrrd from saba-median
# 71.ca.seg.nrrd from saba-mean
# 48.ca.seg.nrrd from saba-median
# 48.ca.seg.nrrd from saba-mean
# 86.ca.seg.nrrd from saba-median
# 86.ca.seg.nrrd from saba-mean
# 24.ca.seg.nrrd from saba-median
# 24.ca.seg.nrrd from saba-mean
# 77.ca.seg.nrrd from saba-median
# 77.ca.seg.nrrd from saba-mean
# 96.ca.seg.nrrd from saba-median
# 96.ca.seg.nrrd from saba-mean
# 49.ca.seg.nrrd from saba-median
# 49.ca.seg.nrrd from saba-mean
# 93.ca.seg.nrrd from saba-median
# 93.ca.seg.nrrd from saba-mean
# 91.ca.seg.nrrd from saba-median
# 91.ca.seg.nrrd from saba-mean
# 94.ca.seg.nrrd from saba-median
# 94.ca.seg.nrrd from saba-mean
# 12.ca.seg.nrrd from saba-median
# 12.ca.seg.nrrd from saba-mean
# 5.ca.seg.nrrd from saba-median
# 5.ca.seg.nrrd from saba-mean
# 14.ca.seg.nrrd from saba-median
# 14.ca.seg.nrrd from saba-mean
# 52.ca.seg.nrrd from saba-median
# 52.ca.seg.nrrd from saba-mean
# 11.ca.seg.nrrd from saba-median
# 11.ca.seg.nrrd from saba-mean
# 87.ca.seg.nrrd from saba-median
# 87.ca.seg.nrrd from saba-mean
# 40.ca.seg.nrrd from saba-median
# 40.ca.seg.nrrd from saba-mean
# 73.ca.seg.nrrd from saba-median
# 73.ca.seg.nrrd from saba-mean
# 53.ca.seg.nrrd from saba-median
# 53.ca.seg.nrrd from saba-mean
# 22.ca.seg.nrrd from saba-median
# 22.ca.seg.nrrd from saba-mean
# 62.ca.seg.nrrd from saba-median
# 62.ca.seg.nrrd from saba-mean
# 65.ca.seg.nrrd from saba-median
# 65.ca.seg.nrrd from saba-mean
# 25.ca.seg.nrrd from saba-median
# 25.ca.seg.nrrd from saba-mean
# 45.ca.seg.nrrd from saba-median
# 45.ca.seg.nrrd from saba-mean
# 64.ca.seg.nrrd from saba-median
# 64.ca.seg.nrrd from saba-mean
# 63.ca.seg.nrrd from saba-median
# 63.ca.seg.nrrd from saba-mean
# 84.ca.seg.nrrd from saba-median
# 84.ca.seg.nrrd from saba-mean
# 21.ca.seg.nrrd from saba-median
# 21.ca.seg.nrrd from saba-mean
# 57.ca.seg.nrrd from saba-median
# 57.ca.seg.nrrd from saba-mean
# 92.ca.seg.nrrd from saba-median
# 92.ca.seg.nrrd from saba-mean
# 75.ca.seg.nrrd from saba-median
# 75.ca.seg.nrrd from saba-mean
# 83.ca.seg.nrrd from saba-median
# 83.ca.seg.nrrd from saba-mean
# 41.ca.seg.nrrd from saba-median
# 41.ca.seg.nrrd from saba-mean
# 90.ca.seg.nrrd from saba-median
# 90.ca.seg.nrrd from saba-mean
# 69.ca.seg.nrrd from saba-median
# 69.ca.seg.nrrd from saba-mean
# 26.ca.seg.nrrd from saba-median
# 26.ca.seg.nrrd from saba-mean
# 79.ca.seg.nrrd from saba-median
# 79.ca.seg.nrrd from saba-mean
# 82.ca.seg.nrrd from saba-median
# 82.ca.seg.nrrd from saba-mean
# 36.ca.seg.nrrd from saba-median
# 36.ca.seg.nrrd from saba-mean
# 97.ca.seg.nrrd from saba-median
# 97.ca.seg.nrrd from saba-mean
# 88.ca.seg.nrrd from saba-median
# 88.ca.seg.nrrd from saba-mean
# 29.ca.seg.nrrd from saba-median
# 29.ca.seg.nrrd from saba-mean
# 23.ca.seg.nrrd from saba-median
# 23.ca.seg.nrrd from saba-mean
# 10.ca.seg.nrrd from saba-median
# 10.ca.seg.nrrd from saba-mean
# 31.ca.seg.nrrd from saba-median
# 31.ca.seg.nrrd from saba-mean
# 27.ca.seg.nrrd from saba-median
# 27.ca.seg.nrrd from saba-mean
# 32.ca.seg.nrrd from saba-median
# 32.ca.seg.nrrd from saba-mean
# 15.ca.seg.nrrd from saba-median
# 15.ca.seg.nrrd from saba-mean
# 51.ca.seg.nrrd from saba-median
# 51.ca.seg.nrrd from saba-mean
# 72.ca.seg.nrrd from saba-median
# 72.ca.seg.nrrd from saba-mean
